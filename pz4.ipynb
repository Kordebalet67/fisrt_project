# %%
import math
a=input().split()
for i in range(0,len(a)):
    a[i]=int(a[i])
choise=int(input())
c=min(a)

match choise:
    case 0:
        print(min(a))
        if a.count(min(a))>=2:
            print(a.count(min(a)))
        pass
    case 1:
        print(max(a))
        if a.count(max(a))>=2:
            print(a.count(max(a)))
    case 2:
        print(min(a))
        print(max(a))
        b=max(a)-min(a)
        for i in range(0,b):
            print(c)
            c+=max(a)

    case 3:
        print(min(a))
        print(max(a))
        b=max(a)-min(a)
        for i in range(0,b):
            print(c)
            c*=max(a)
            
    case _:
        s=int(sum(a)/len(a))
        print(s)
        if s<0:
            print(0)
        else:
            s=math.factorial(s)
            print(s)
# Out:
# 3
# 6

# %%
def main():
    pass

if __name__ == '__main__':
    main()
