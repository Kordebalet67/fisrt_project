# %% [markdown]
# # Оператор if

# %%
a = 34536
if a % 2 == 0:
    print("Чётное")
# Out:
# Чётное

# %%
a = 34536
if a % 2 == 0:
    print("Чётное")
else:
    print("Не чётное")
# Out:
# Чётное

# %%
x = 1
if x == 0:
    print("neutral")
elif x < 0:
    print("negative")
elif x > 0:
    print("positive")
# Out:
# positive

# %% [markdown]
# # Конструкция match-case

# %%
x = 2
match x:
    case 0:
        print("0")
    case 1:
        print("1")
    case -1:
        print("-1")
    case _:
        print("smth big")
# Out:
# smth big

# %% [markdown]
# # оператор while

# %%
b = 417228

while True:
    b = b / 2
    print(b)
    if b < 1:
        break
# Out:
# 208614.0
# 104307.0
# 52153.5
# 26076.75
# 13038.375
# 6519.1875
# 3259.59375
# 1629.796875
# 814.8984375
# 407.44921875
# 203.724609375
# 101.8623046875
# 50.93115234375
# 25.465576171875
# 12.7327880859375
# 6.36639404296875
# 3.183197021484375
# 1.5915985107421875
# 0.7957992553710938

# %% [markdown]
# # оператор for

# %% [markdown]
# a[0] = a[0] + 1           <=>           a[0] += 1

# %%
a = list(range(1,10))
for iter in range(0, len(a) - 1):
    a[iter] += 1
    print(a[iter])
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
a = list(range(1,10))
for item in a:
    item += 1
    print(item)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
for i in range(1, 10):
    pass

# %%
a = 34627
iter = 0

while iter < a:
    iter += 1

print(iter)
# Out:
# 34627

# %%
a = 34627

for iter in range(0, 1_000_000):
    if iter == a:
        break

print(iter)
# Out:
# 34627

# %%
n = int(input("Введите N: "))
z = 0
print (n)

if n == 0:
    print("Количество шагов равно нулю")
while n!=0: 

    if n%3 == 0:
        n =int((n-10)/2)
        z = z + 1
    elif n%2 == 0:
        n = int((n*3))
        z = z + 1
    elif n%5 == 0:
        n = int(n**0.5)  
        z = z + 1
    elif n%7 == 0:
        n = int(n**(1/3))
        z = z + 1 
    else:
        n-=1 
        z = z + 1
    if z > 1_000_000:
        print("Количество шагов бесконечность")
        break
if z <= 1_000_000:
    print ("Количество шагов :",z)
# Out:
# 567
# Количество шагов бесконечность

# %%
from tqdm import tqdm

for i in tqdm(range(1_000_000_000)):
    a = i+1

# %%
a = (input()).split()
b = 0
for i in range(0, len(a)):
    a [i] = int(a[i])
choise = int(input('Выберпите операцию'))
match choise:
    case 0:
        for i in range(0, len(a)):
            a[i] = 0 
    case 1:
        for i in range(0, len(a)):
            a[i] =a[i] * 2
    case 2:
        for i in range(0, len(a), 2):
            a[i] = a[i] +10
    case 3:
        for i in range(0, len(a), 3):
            if a[i] >= 0:
                a[i] = a[i] ** 0.5
            else:
                a[i] = 0
    case _: 
        b = sum(a)     #  for i in range(0, len(a)):
                             #b += a[i]
print(a)
print(b)
# Out:
# [1, 2, 3, 4, 5]
# 15
